# %% [markdown]
# MC simulation, Exercises 7

# %%
"""1. part B"""
#n, bins, patches = hist(samples,50,normed=True,label="Sampled data")
#plot(x,y*max(n),'r-',label='True distribution')
# Out:
#   File "<ipython-input-2-c119db62a45f>", line 1
#     1. part B
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2.
# =

# %% [markdown]
# #$f(x)= \alpha\beta^{-\alpha}x^{\alpha-1}e^{-(x/\beta)^{\alpha}}$ x >0
#
# Used Wolfram to get $F(x)$ and $F^{-1}(x)$
#
# #$F(x) = 1+e^{-(\frac{x}{\beta})^{\alpha}}$
# (part a)
# #$F^{-1}(x) = \beta[-ln(1-x)]^{\frac{1}{\alpha}}$ (part b)

# %%
import numpy 
import numpy.random as random
f = lambda x: a*(b**(-a))*(x**(a-1))*(e**(-(x/b)**a))
#F = lambda x: 1+(e**(-(x/b)**a)
#Finv = lambda x: b(-log(1-x))**(1/a)
x = arange(0.,30. +0.001,0.01)
a = 1.5
b = 6
CDF = np.cumsum(f(x))/sum(f(x))
N = 10000
z = numpy.random.random_sample(N)
Finv = x[np.searchsorted(CDF,z)]
plot(x,CDF, label = "CDF")
plot(x,f(x),label='True distribution', lw=3, color='red')
hist(Finv,100,normed=True, color = "yellow",label="Samples distirbution") 
legend(loc = 0)
show()
# Out:
# [  0.00000000e+00   1.02058713e-04   2.46373574e-04 ...,   9.99999844e-01
#    9.99999922e-01   1.00000000e+00]

# %% [markdown]
# 3.
# =

# %% [markdown]
# $f(x) = 60x^3(1-x)^2$ 0 <= x <= 1
#
#
# $f(x)= 0$ otherwise

# %% [markdown]
# a) Rejection Sampling method

# %%
f = lambda x: (60*x**3)*((1-x)**2)
x = arange(0.,1.,0.001)

N = 10000.
xmin = 0.
xmax = 1.0
#subx = x[logical_and((x > xmin),(x < xmax))]
ymax = 2.5
ymin = 0.
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);
newmask = (samples_y < f(samples_x))
myplot = plot(x,f(x),lw=3)
xlim(0.,1.01)
plot(samples_x[1:200],samples_y[1:200],'.')

plot([xmin, xmin], [ymin, ymax], color = 'k', linestyle = '--') #vertical left
plot([xmax, xmax], [ymin, ymax], color = 'k', linestyle = '--') #vertical right
plot([xmin, xmax], [ymax, ymax], color = 'k', linestyle = '--') #horizontal top
show()
sum(newmask)
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 1.0025

# %% [markdown]
# part b)

# %%
f = lambda x: (60*x**3)*((1-x)**2)
CDF = np.cumsum(f(x))/sum(f(x))
N = 10000
z = numpy.random.random_sample(N)
Finv = x[np.searchsorted(CDF,z)]
plot(x,CDF, label = "CDF")
plot(x,f(x),label='True distribution', lw=3, color='red')
hist(Finv,100,normed=True, color = "yellow",label="Samples distirbution") 
legend(loc = 0)
show()
