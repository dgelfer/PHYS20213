# %% [markdown]
# Midterm
# =

# %% [markdown]
# 2. plotting
# =

# %% [markdown]
# part a)

# %%
import math
import scipy
import scipy.integrate as integrate

y = lambda x: (cos(2*(2*x)*cos(x/2))**2)

xticks(np.arange(-pi,pi+0.1, pi/4),("$-\pi$","$-3\pi/4$","$-\pi/2$","$-\pi/4$","0.0","$\pi/4$","$\pi/2$","$3\pi/4$","$\pi$"))
x = arange(-pi,pi+0.1,0.1)
plot(x, y(x), lw = 2 , label = " y($\theta$)"  , color = 'red')
plot(x, y(x), lw = 2 , label = " y($\theta$)" , color = 'blue', linestyle = '--')
title ("y($\theta$) vs $\theta$")
xlabel("$\theta$ rad")
ylabel ("y($\theta$)")
legend()
show()

# %% [markdown]
# part b)

# %%
f = lambda x: ((1+x)/(x-1))
e = lambda x: (exp(-x))    # come back later

xticks(np.arange(-4,4+0.5,2))
x = arange(-4,4.5,0.01)
ylim(-10.,10.,5.)
plot(x, f(x), lw = 2 , label = "(1+t)/(t-1)"  , color = 'red')
plot(x, e(x), lw = 2 , label = "exp(-x)" , color = 'blue')
title ("different functions")
xlabel("time seconds")
ylabel ("f(t), g(t)")
legend()
show()

# %% [markdown]
# 3)
# =
# a)

# %%
#def pointField(x,y,q,Xq,Yq):
     #Ex = (k*q)(x-Xq)/((((x-Xq)**2)+(y-Yq)**2))**(1./2.)
         #return Ex
     #Ey = (k*q)(y-Yq)/((((x-Xq)**2)+(y-Yq)**2))**(1./2.)
        #return Ey
""" what I have in my nano for electronics which pretty much says it a function of that returns Ex and Ey  arrayswith aproriate variables as described"""

# %%
import math
import scipy
import scipy.integrate as integrate
import sys
sys.path.insert(0, '../Week4')
from Electrostatics import *

#x = arange(1.0,2.0,0.1)

#dx = diff(x)
a = 1 
b = 2
x_diff = b-a 
gema = 1e-6 # # charge density is 1.0 microC/M

N =1e-6;
x0 = 3.;
y0 = 3.;
Xq = 1. + 2.001*random_sample(N); 
Yq = 0. + 2.001*random_sample(N);
Ei = pointField(x0,y0,gema,Xq,Yq)
Etot = (2.*2./N)*sum(Ei)
print Etot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-6c68d1dfff4f> in <module>()
#      20 Xq = 1. + 2.001*random_sample(N);
#      21 Yq = 0. + 2.001*random_sample(N);
# ---> 22 Ei = pointField(x0,y0,gema,Xq,Yq)
#      23 Etot = (2.*2./N)*sum(Ei)
#      24 print Etot
#
# /Users/dangelfer/PHYS20213/Week4/Electrostatics.py in pointField(x, y, q, Xq, Yq)
#      16 def pointField(x,y,q,Xq,Yq):
#      17      k = 9.e9
# ---> 18      Ex = (k*q)(x-Xq)/((((x-Xq)**2)+(y-Yq)**2))**(1./2.)
#      19 return Ex
#      20      Ey = (k*q)(y-Yq)/((((x-Xq)**2)+(y-Yq)**2))**(1./2.)
#
# TypeError: 'float' object is not callable

# %% [markdown]
# 4)
# =
# a)
# =

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'
suffix2 ='uack'
for letter in prefixes:
    if letter == 'O' and 'Q':
        print letter + suffix2
    else:
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Qack
