# %% [markdown]
# Project Euler 17
# ==
#
#
# If the numbers 1 to 5 are written out in words: one, two, three, four, five, then there are 3 + 3 + 5 + 4 + 4 = 19 letters used in total.
#
# If all the numbers from 1 to 1000 (one thousand) inclusive were written out in words, how many letters would be used?
#
#
# NOTE: Do not count spaces or hyphens. For example, 342 (three hundred and forty-two) contains 23 letters and 115 (one hundred and fifteen) contains 20 letters. The use of "and" when writing out numbers is in compliance with British usage.

# %%
""" I created dictionaries for 1-9,10-19,20-90 (steps of ten) in order to call on their elements for convenience"""
counter_nine = 0
counter_nineteen = 0
counter_twenties1 = 0 
counter_twenties2 = 0
counter_thirties1 = 0
counter_thirties2 = 0
counter_forties1 = 0
counter_forties2 = 0
counter_fifties1 = 0 
counter_fifties2 = 0
counter_sixties1 = 0 
counter_sixties2 = 0
counter_seventies1 = 0
counter_seventies2 = 0
counter_eighties1 = 0
counter_eighties2 = 0
counter_nineties1 = 0
counter_nineties2 = 0
counter_1000 = 0
variable1 = 'hundred'
variable2 = 'hundredand'
variable3 = 'thousand' 
one_ninetynine = 0
hundred_999_a = 0
one_nine = { 
            1:'one',
            2:'two',
            3:'three',
            4:'four',
            5:'five',
            6:'six', 
            7:'seven',
            8:'eight',
            9:'nine'}
ten_nineteen = {
                10:'ten',
                11:'eleven',
                12:'Twelve',
                13:'thirteen',
                14:'fourteen',
                15:'fifteen',
                16:'sixteen',
                17:'seventeen',
                18:'eighteen',
                19:'nineteen'}
twenty_ninety = {
                 20:'twenty',
                 30:'thirty',
                 40:'forty',
                 50:'fifty',
                 60:'sixty',
                 70:'seventy', 
                 80:'eighty',
                 90:'ninety'}
    
for n in range(1,10): # counts letters from 1-9
    counter_nine += len(str(one_nine[n]))
for n in range(10,20): # counts letters from 10-19
    counter_nineteen += len(str(ten_nineteen[n]))
for n in range(1,10): # for all values of 20-29
    counter_twenties1 += len(str(twenty_ninety[20]))+len(str(one_nine[n]))
    counter_twenties2 = counter_twenties1 + len(str(twenty_ninety[20]))
for n in range(1,10): # for all values of 30-39
    counter_thirties1 += len(str(twenty_ninety[30]))+len(str(one_nine[n]))
    counter_thirties2 = counter_thirties1 + len(str(twenty_ninety[30]))
for n in range(1,10): # for all values of 40-49
    counter_forties1 += len(str(twenty_ninety[40]))+len(str(one_nine[n]))
    counter_forties2 = counter_forties1 + len(str(twenty_ninety[40]))
for n in range(1,10): # for all values of 50-59
    counter_fifties1 += len(str(twenty_ninety[50]))+len(str(one_nine[n]))
    counter_fifties2 = counter_fifties1 + len(str(twenty_ninety[50]))
for n in range(1,10): # for all values of 60-69
    counter_sixties1 += len(str(twenty_ninety[60]))+len(str(one_nine[n]))
    counter_sixties2 = counter_sixties1 + len(str(twenty_ninety[60]))
for n in range(1,10): # for all values of 70-79
    counter_seventies1 += len(str(twenty_ninety[70]))+len(str(one_nine[n]))
    counter_seventies2 = counter_seventies1 + len(str(twenty_ninety[70]))
for n in range(1,10): # for all values of 80-89
    counter_eighties1 += len(str(twenty_ninety[80]))+len(str(one_nine[n]))
    counter_eighties2 = counter_eighties1 + len(str(twenty_ninety[80]))
for n in range(1,10): # for all values of 90-99
    counter_nineties1 += len(str(twenty_ninety[90]))+len(str(one_nine[n]))
    counter_nineties2 = counter_nineties1 + len(str(twenty_ninety[90]))
    one_ninetynine = counter_nine+counter_nineteen+counter_twenties2+counter_thirties2+counter_forties2+counter_fifties2+counter_sixties2+counter_seventies2+counter_eighties2+counter_nineties2    
print one_ninetynine

for n in range(1,10):# for 100-999 , the term ser 1-9 will be repeated 100 times since each nth hundred term will start with one , two, three  ... Then the term "hundred and" will be repeated 99 times per each nth hundred for 100-999. 
    hundred_999_a += 100*(len(str(one_nine[n])))+len(variable1)+(one_ninetynine)+ 99*(len(variable2))
print hundred_999_a 
counter_1000 =  hundred_999_a + one_ninetynine + len(variable3) + len(str(one_nine[1])) # add all letter counts for 1-99 , 100-999, and 1000.
    
print counter_1000, 'Final Value'
# Out:
# 854
# 20259
# 21124 Final Value
