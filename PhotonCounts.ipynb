# %%
#increase High voltage see bigger pulse height

# %%
#FWHM=40 ns

# %%
#Discriminator=D
D1=-5 #mV
C1=5670229
D2=-10
C2=3350383
D3=-15
C3=1530492
D4=-20
C4=467258
D5=-30
C5=42902
D6=-40
C6=6006
D7=-50
C7=2013
D8=-60
C8=1323
D9=-80
C9=798
D10=-100
C10=426
D11=-120
C11=260

# %%
#Dark Counts
D1d=-5 #mV
C1d=4553./10.
D2d=-10  #divide by 10 second acquiring time
C2d=996./10.
D3d=-15
C3d=610./10.
D4d=-20
C4d=142./10.
D5d=-30
C5d=10./10.
D6d=-40
C6d=4./10.
D7d=-50
C7d=2./10.
D8d=-60
C8d=1./10.
D9d=-80
C9d=1./10.
D10d=-100
C10d=1./10.
D11d=-120
C11d=1.


Disc=[-5,-10,-15,-20,-30,-40,-50,-60,-80,-100,-120]
Cd=[C1d,C2d,C3d,C4d,C5d,C6d,C7d,C8d,C9d,C10d,C11d] #background
C=[C1,C2,C3,C4,C5,C6,C7,C8,C9,C10,C11]

# %%
S_N=[]
for i in range(len(C)):
    S_N.append(C[i]/Cd[i])
print S_N
plot(Disc,S_N)
title('S/N vs discriminator')
xlabel('Discriminator voltage (mV)')
ylabel('S/N')

#Thus optimal discrimination is at -30 mV
# Out:
# [12453.830441467164, 33638.38353413655, 25090.032786885247, 32905.49295774648, 42902.0, 15015.0, 10065.0, 13230.0, 7980.0, 4260.0, 260.0]
