# %% [markdown]
# 1.
# =
# It is common to test functions where you know the answer. Let's test the dipolePotential()
# function that you previously wrote and saved in a python script to see that the function is
# zero along the bisector between the charges. First, set up a grid and evaluate the function.

# %%
from Electrostatics import *
x,y = meshgrid(arange(-5,5,0.5),arange(-5,5,0.5))
Vdipole = dipolePotential(x,y,1e-9,2.);
contour(x,y,Vdipole,cmap=cm.coolwarm)
xlabel('x(m)')
ylabel('y(m)')
title('Dipole potential')
show()

# %% [markdown]
# a)

# %%
mask = (y == 0)

# %% [markdown]
# B)

# %%
print Vdipole[mask]
# Out:
# [ -0.75        -0.93506494  -1.2         -1.6         -2.25        -3.42857143
#   -6.         -14.4                -inf -12.           0.          12.
#           inf  14.4          6.           3.42857143   2.25         1.6
#    1.2          0.93506494]

# %% [markdown]
# 2)

# %%
from scipy.interpolate import interp1d
data = loadtxt("/Users/dangelfer/PHYS20213/Week4/Thermister.txt",float)
x = data[:,0] # degrees coulombs
y = data[:,1]#degrees omega
    
def Temp(Resistance): # I have no idea how to interp otherwise because I do not understand the relationship between resistance and temperature other then interping both  the resistance and temperature data points.
    TempInterp = interp1d(x,y)
    return TempInterp

# %%
def Temp(resistance):
# Out:
#   File "<ipython-input-22-0092514ee6fc>", line 1
#     def Temp(resistance):
#                          ^
# SyntaxError: unexpected EOF while parsing

# %%
plot(x,y)

# %% [markdown]
# 3)
# =

# %% [markdown]
# a)

# %%
def finiteDifference(x,y):
    dy = diff(y)
    dx = diff(x)
    dydx = dy/dx
    dydx1 = zeros(y.shape,float)
    dydx1[1:-1] =(y[2:]-y[:-2])/(x[2:]-x[:-2]) 
    dydx1[0] =(y[1]-y[0])/(x[1]-x[0])
    dydx1[-1] = (y[-1] - y[-2])/(x[-1]-x[-2])
    return dydx1

# %% [markdown]
# b)

# %%
x = arange(0.,10.,0.1)
y = x**5
plot(x,finiteDifference(x,y),label = "center difference")

# %% [markdown]
# c)

# %%
x = arange(0.,10.,0.001)
y = x ** 5
accuratedydx = 5*x**4
plot(x, finiteDifference(x,y), label = "center difference")
plot(x, accuratedydx, label = "correct derivative")
xlabel("x")
ylabel("y")
title("Derivative of $x^5$")
legend(loc = "upper left")
show()

# %%
plot(x,(accuratedydx - finiteDifference(x,y)), label="Difference")
title( "Difference between accurate derivative and finiteDifference")
xlabel("x")
ylabel("y")
legend()
show()

# %% [markdown]
# d)

# %%
x = arange(0.,10.,0.001)
y = x ** 5
accuratedydx = 5*x**4
print accuratedydx - finiteDifference(x,y)
# Out:
# [ -1.00000000e-12  -1.10000000e-11  -4.10000000e-11 ...,  -9.99400036e-04
#   -9.99600437e-04   9.99600055e+00]

# %% [markdown]
# 4)
# =

# %% [markdown]
# a)

# %%
x = linspace(0,2*pi,100)
y = sin(x) + 0.1*random.random(size=x.shape)
plot(x,y)
show()

# %% [markdown]
# b)

# %%
def fourPtFiniteDiff(x,y): 
    dy = diff(y)
    dx = diff(x)
    dydx = dy/dx
    dydx1 = zeros(y.shape,float)
    dydx1[2:-2] =(y[3:]-y[:-3])/(x[3:]-x[:-3]) # derivative from the third number to second to the last one.
    dydx1[0] =(y[1]-y[0])/(x[1]-x[0])# derivative of the first item
    dydx1[-1] = (y[-1] - y[-2])/(x[-1]-x[-2]) #derivative of the last item
    dydx1[1] =(y[2]-y[1])/(x[2]-x[1])# derivative of the second item
    dydx1[-2] = (y[-2] - y[-2])/(x[-1]-x[-2])# derivative of the second to last
    return dydx1

# %%
x = arange(0.,10.,0.001)
y = x ** 5
accurate2dydx = 5*x**4 

plot(x,dydx1,label = 'four point center difference')
plot(x,accurate2dydx, label='exact derivative')
legend(loc = 'upper left')
show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-98e74ef38f3c> in <module>()
#       3 accurate2dydx = 5*x**4
#       4
# ----> 5 plot(x,dydx1,label = 'four point center difference')
#       6 plot(x,accurate2dydx, label='exact derivative')
#       7 legend(loc = 'upper left')
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    2456         ax.hold(hold)
#    2457     try:
# -> 2458         ret = ax.plot(*args, **kwargs)
#    2459         draw_if_interactive()
#    2460     finally:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in plot(self, *args, **kwargs)
#    3846         lines = []
#    3847
# -> 3848         for line in self._get_lines(*args, **kwargs):
#    3849             self.add_line(line)
# ...

# %% [markdown]
# not sure why im having an error. I will see you in office hours.
