# %% [markdown]
# electric potential
#
# $V(x,y) = \frac{kq}{\sqrt{x^2+(y-d)^2}} - \frac{kq}{\sqrt{x^2+(y+d)^2}}$

# %%
#make the x-y grid to cover the plane  -2<x<2 and -2<y<2
dx = 0.06
dy = 0.06
x = arange(-2.,2.,dx)
y = arange(-2.,2.,dy)
X,Y =  meshgrid(x,y)
print X.ndim
print Y
# make the function V(x,y)
k = 1; q = 1; d = 1 # note the power of half has a dot at 2

V = (k*q/(X**2+(Y-d)**2)**(1/2.)) - (k*q/(X**2+(Y+d)**2)**(1/2.))
print V
# Out:
# 2
# [[-2.   -2.   -2.   ..., -2.   -2.   -2.  ]
#  [-1.94 -1.94 -1.94 ..., -1.94 -1.94 -1.94]
#  [-1.88 -1.88 -1.88 ..., -1.88 -1.88 -1.88]
#  ...,
#  [ 1.84  1.84  1.84 ...,  1.84  1.84  1.84]
#  [ 1.9   1.9   1.9  ...,  1.9   1.9   1.9 ]
#  [ 1.96  1.96  1.96 ...,  1.96  1.96  1.96]]
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.ocean_r)
# help(Axes3D.plot_surface())
cb = fig.colorbar(p, shrink=0.8)

# %%
#Represent 3D data by contours
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.50, -1, -2, -4, -8])
contour(X,Y,V,levels,linewidth=3,cmap=cm.gist_heat)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10f9933b0>

# %% [markdown]
# Ex.1 MAke a 3-D plot of the function
# =
# $G(x,y) = e^{-x^2-y^2}$    over the range -6<(x,y)<6 using 51 bins in x and 51 bins in y

# %%
dx = 12./51.
dy = 12./51.
x = arange(-6.,6.,dx)
y = arange(-6.,6.,dy)
X,Y = meshgrid(x,y)
G = exp(-X**2-Y**2)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, G, rstride=1, cstride=1,linewidth=0, cmap=cm.ocean_r)
# help(Axes3D.plot_surface())
cb = fig.colorbar(p, shrink=0.8)

# %% [markdown]
# Ex.2
# =
# : determine the electric potential for a quadrupole consisting q= -1.0nC a both(x= +/-2, y=0), and q=+1.0 nC at both (x=0, y=+/- 2). Make a surface plot and a contour plot on the range -4<x,y<4
# using 101 bins in x and 101 bins in y. What is the value of the function at V(20,30)?

# %%
dx = 8./101.
dy = 8./101.
x = arange(-4.,4.,dx)
y = arange(-4.,4.,dy)
X,Y =  meshgrid(x,y)
  # N * m^2 / C^2 , C, m (meters)
k = 9e9; q1= -1e-9; d = 2; q2= 1e-9 

V = (k*q/(X**2+(Y-d)**2)**(1/2.)) - (k*q/(X**2+(Y+d)**2)**(1/2.)) + (k*q2/((X-d)**2+Y**2)**(1/2.)) - (k*q2/((X+d)**2+Y**2)**(1/2.))

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(X, Y, V, rstride=1, cstride=1, linewidth=0, cmap=cm.ocean_r)

cb = fig.colorbar(p, shrink=0.8)

# %%
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.50, -1, -2, -4, -8])

dx = 0.08
dy = 0.08
x = arange(-4.,4.,dx)
y = arange(-4.,4.,dy)
X,Y =  meshgrid(x,y)
k = 9e9; q1= -1e-9; d = 2; q2= 1e-9 
V = (k*q1/(X**2+(Y-d)**2)**(1/2.)) - (k*q1/(X**2+(Y+d)**2)**(1/2.)) + (k*q2/((X-d)**2+Y**2)**(1/2.)) - (k*q2/((X+d)**2+Y**2)**(1/2.))

contour(X,Y,V,levels,linewidth=3,cmap=cm.gist_heat)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10bb3c3f8>

# %% [markdown]
# Exercise 3
# =

# %% [markdown]
# w we want to refactor the code we wrote in the example and
#
#
# rst exercise to make
#
#
#
# it more useful. In this exercise, you will encapsulate your electric potential calculations
#
#
#
# within functions.
#
#
#
# (a) The
#
#
# rst function should be named pointPotential(). It should take as arguments
#
#
#
# the point or points in space where you want to know the potential, the size (and sign) of
#
#
#
# the charge q and the position of the charge in the plane, and return the electric potential
#
#
#
# due to that charge. Here is the skeleton:PHYS 202 - Sp2013 - Klay 4
#
#
#
# def pointPotential(x,y,q,posx,posy):
#
#
#
# """Be sure to include a docstring to explain what this function does"""
#
#
#
# ...your code goes here...
#
#
#
# return Vxy
#
#
#
# Note that x,y could be single values or numpy arrays. Python will
#
#
# gure out what to return
#
#
#
# based on what you use to call the function. To see what this means, call the function in
#
#
#
# the following two ways:
#
#
#
# x = 1.; y = 1.
#
#
#
# V11 = pointPotential(x,y,1e-9,0.,0.)
#
#
#
# print V11
#
#
#
# x,y = meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
#
#
#
# Vxy = pointPotential(x,y,1e-9,0.,0.)
#
#
#
# print Vxy
#
#
#
# (b) Next, create another function named dipolePotential(), that takes as arguments
#
#
#
# the point or points in space where you want to know the potential, the size of the charges
#
#
#
# q, and the separation distance d between the charges. This function should call the
#
#
#
# pointPotential function you created in part (a) and return the electric potential due
#
#
#
# to the dipole. For simplicity, let the two charges lie along the x-axis with their midpoint
#
#
#
# at the origin. Here is the skeleton:
#
#
#
# def dipolePotential(x,y,q,d):
#
#
#
# """Be sure to include a docstring to explain what this function does"""
#
#
#
# ...your code goes here...
#
#
#
# return Vxy
#
#
#
# Bonus: For an additional challenge, add an argument to the dipolePotential() for the
#
#
#
# angle that the dipole axis makes with the x-axis. This will allow you to create o
#
#
# -axis
#
#
#
# dipoles.
#
#
#
# (c) Finally, use these newly created functions to remake the 3D plots of the dipole and
#
#
#
# quadrupole that we did in class.

# %% [markdown]
# a)

# %%
def pointPotential(x,y,q,posx,posy): # this function finds the potential between the particle's location and wanted distance.
  q = 1.6e-19; k = 9e9
  Vxy = ((k*q)/sqrt((x-posx)**2)+(y-posy)**2)
  
  return Vxy
x = 2.; y = 2.
V22 = pointPotential(x,y,1.6e-19,0.,0.)
print V22
# Out:
# 4.00000000072

# %% [markdown]
# b)

# %%
def dipolePotential(x,y,q,d): # finds dipole potential at a certain distance d
    k = 9e9; q = 1.6e-19; 
    Vxy_2 = (k*q/(x**2+(y-(d/2))**2)**(1/2.)) - (k*q/(x**2+(y+(d/2))**2)**(1/2.))
    return Vxy_2
x = 2.; y = 2.
V22_2 = dipolePotential(x,y,q,2)
print V22_2
dipolePotential(x,y,1.6e-19,2)
# Out:
# 2.44603436238e-10
# 2.4460343623777437e-10

# %% [markdown]
# c)

# %%
k = 9e9; q = 1.6e-19 # I don't know why this is no working!!!!!!!
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, pointPotential(x,y,1.6e-19,0.,0.), rstride=1, cstride=1, linewidth=0, cmap=cm.ocean_r)
g = ax.plot_surface(x, y, dipolePotential(x,y,1.6e-19,2), rstride=1, cstride=1, linewidth=0, cmap=cm.ocean_r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-49358afafcd9> in <module>()
#       1 k = 9e9; q = 1.6e-19 # I don't know why this is no working!!!!!!!
#       2 fig = figure()
# ----> 3 ax = fig.gca(projection='3d')
#       4 p = ax.plot_surface(x, y, pointPotential(x,y,1.6e-19,0.,0.), rstride=1, cstride=1, linewidth=0, cmap=cm.ocean_r)
#       5 g = ax.plot_surface(x, y, dipolePotential(x,y,1.6e-19,2), rstride=1, cstride=1, linewidth=0, cmap=cm.ocean_r)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1051             if isinstance(ax, projection_class):
#    1052                 return ax
# -> 1053         return self.add_subplot(111, **kwargs)
#    1054
#    1055     def sca(self, a):
#
# ...
