# %% [markdown]
# ##Magnetic Field vs Current

# %%
#amps and mT?
B1=4.2
I1=0
B2=1098.0
I2=1.13
B3=1902.4
I3=2.02
B4=2908.9
I4=3.07
B5=3704.7
I5=4
B6=4463.7
I6=5.02
B7=4971.8
I7=6
B8=5274.4
I8=7.01
B9=5381.0
I9=7.46
B=array([B1,B2,B3,B4,B5,B6,B7,B8,B9])
I=array([I1,I2,I3,I4,I5,I6,I7,I8,I9])
scatter(I,B)
xlim(-.5,8)
ylim(-5,6000)
xlabel('Current (A)')
ylabel('B (mT)')
show()

# %%
#Central Peaks

# %%
a1=-.535
a2=.845
zeroshift=(a1+a2)/2.
print zeroshift
# Out:
# 0.155

# %%
#1st Scan

# %%
def Calib(x,a,b,c,d):
    return x**3*a+x**2*b+x*c+d
p=[.2,.3,1,4]
from scipy.optimize import curve_fit  # import the curve fitting function
plsq, pcov = curve_fit(Calib, I, B, p)

# %%
xlots=linspace(0,10,1000)
plot(xlots,Calib(xlots,plsq[0],plsq[1],plsq[2],plsq[3]))
scatter(I,B)
A_=plsq[0]
B_=plsq[1]
C_=plsq[2]
D_=plsq[3]
xlim(0,8)
print A_,B_,C_
# Out:
# -8.30284409669 35.612315093 913.698909584

# %%
def Calibration(x):
    return x**3*A_+x**2*B_+x*C_+D_

# %%
uncI=[.1,.1,.1,.1,.1,.1,.1,.1,.1]
uncB=[]
for i in range(shape(I)[0]):
    uncB.append((A_*I[i]**2*3+2*B_*I[i]+C_)*uncI[i])
print uncB
# Out:
# [91.369890958401868, 96.2377036812981, 95.593588740330716, 89.759809827434651, 80.006091368692296, 64.354157599514323, 44.433952825766156, 18.897579960087491, 5.8834975177836331]

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plot(xlots,Calibration(xlots))
scatter(I,B)
errorbar(I, B, yerr=uncB, xerr=uncI,fmt='.')
xlim(-.1,8)
ylim(-100,6000)
xlabel('$I$ (A)',fontsize=14)
ylabel('$B$ (mT)',fontsize=14)
show()

# %%
a1_unshifted=-.631
a2=-.690
B11=Calibration(3.03)

a3=-.727
B12=Calibration(4.02)

a4=-.732
B13=Calibration(4.31)

a5=-.743
B14=Calibration(5.02)

a6=-.748
B15=Calibration(5.52)

a7=-.754
B16=Calibration(6)

a8=-.764
B17=Calibration(6.49)


a9=-.764
B18=Calibration(7.02)
print B18
a10=-.775
B19=Calibration(7.5)
print B19

ii=array([3.03,4.02,4.31,5.02,5.52,6,6.49,7.02,7.5])
# Out:
# 5305.27177986
# 5361.64419156

# %%
b1=.808

B21=Calibration(2.17)
b2=.77
b3=.760
B22=Calibration(2.49)

b4=.749
B23=Calibration(3.04)

b5=.727
B24=Calibration(3.5)

                
b6=.711
B25=Calibration(4.0)

b7=.706
B26=Calibration(4.5)

b8=.695
B27=Calibration(5)

b9=.69
B28=Calibration(5.5)

b10=.685
B29=Calibration(6.0)

b11=.674
B210=Calibration(7)
B210

iii=array([2.17,2.49,3.04,3.54,4.5,5,5.5,6,7])

# %%
Slope_top=4.81 #microeV/Tesla
Slope_bot=-5.09

# %%
#Magnetic Field
Q_up=array([0,2.87,3.72,3.94,4.44,4.74,4.98,5.17,5.31,5.36])
Q_do=array([0,2.07,2.38,2.88,3.29,3.7,4.08,4.43,4.73,4.98,5.3])

#Delta E
E_up=array([0,10.7,17.9,18.9,21.2,22.2,23.4,25.5,25.5,27.9])
E_do=array([0,-8.3,-10.4,-12.6,-17.1,-20.3,-21.2,-23.4,-24.3,-25.3,-27.3])

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
scatter(Q_up,E_up)
xlabel('$B$ (T)')
ylabel('$\Delta E$ ($\mu$eV)')

# %%
def Lin(a,x):
    return a*x
p_0=[1]
from scipy.optimize import curve_fit  # import the curve fitting function
plsq, pcov = curve_fit(Lin, Q_up, E_up, p_0)
rr=plsq[0]

xlots2=linspace(0,6,1000)

from scipy.optimize import curve_fit  # import the curve fitting function
plsq, pcov = curve_fit(Lin, Q_do, E_do, p_0)
ss=plsq[0]

# %%
uncB_up=[]
for i in range(shape(ii)[0]):
    uncB_up.append((A_*ii[i]**2*3+2*B_*ii[i]+C_)*.01)
print uncB_up

uncB_do=[]
for i in range(shape(ii)[0]):
    uncB_do.append((A_*iii[i]**2*3+2*B_*iii[i]+C_)*.01)
print uncB_do

uncE_up=[]
uncE_do=[]
# Out:
# [9.0082679494568243, 7.9749007771131675, 7.5797367901214967, 6.4354157599514314, 5.4788592591951177, 4.4433952825766152, 3.2679688858039082, 1.8619337882243907, 0.46778694662903375]
# [9.5096456938689933, 9.366128476954712, 9.0002709333753543, 8.536903371962218, 7.2981196654715221, 6.4710875326235167, 5.5195127383252149, 4.4433952825766152, 1.917532386728525]

# %%
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
scatter(Q_up,E_up)
plot(xlots2,Lin(rr,xlots2))
xlabel('$B$ (T)',fontsize=14)
ylabel('$\Delta E$ ($\mu$eV)', fontsize=14)
xlim(0,6)
scatter(Q_do,E_do,c='g')
plot(xlots2,Lin(ss,xlots2))
#errorbar(Q_up, E_up,yerr=uncE_up, xerr=uncB_up,fmt='.')
#errorbar(Q_do,E_do, yerr=uncE_up, xerr=uncB_up,fmt='.')
show()

# %%
E_up_th=[]
for i in range(

# %%
#def Delt_E(a):
   # c=3*10**8.
 #   h=6.626*10**-34.
   # hc=h*c
   # f=150*10**-3
   # n=1.46
   # Lam=642.8*10**-9
    #R=hc*(2*f*sqrt((n**2.)-(sin(a))**2.)-Lam)/(Lam**2.)
    #return R*10**6.

#Delt_E(.5)
# Out:
# 1.9902992260784944e-07

# %%
def Delt_E(B):
    return (((1.055*10**-34)/2)*1.759*10**11)*B
((Delt_E(5))*6.24150934*10**18.)*10**5
# Out:
# 28.95662437539575
